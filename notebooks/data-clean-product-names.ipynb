# %% [markdown]
# this notebook takes the brand names or product names, cleans them by removing duplicates, sorting in alphabetical order, putting them as lower case and then printing them on screen.

# %%
BLOCKED_BRANDS = [
    "boat", "bajaj", "portronics", "wayona", "noise", "ambrane", "zebronics", "zebronics",
    "crompton", "prestige", "agaro", "classmate", "lifelong", "pigeon", "boult", "7seven",
    "striff", "gizga", "lapster", "ptron", "usha", "eureka", "ibell", "flix", "sujata",
    "wipro", "kent", "havells", "butterfly", "tukzer", "prettykrafts", "robustrion",
    "kuber", "storite", "parker", "vw", "digitek", "aircase", "borosil", "hul",
    "instacuppa", "sounce", "tata", "maharaja", "bulfyss", "healthsense", "lint",
    "inalsa", "electvision", "cello", "swapkart", "e cosmos", "synqe", "e-cosmos",
    "ecosmos", "elv", "zoul", "amozo", "tygot", "orpat", "croma", "pinnaclz", "tvara",
    "kitchen", "popio", "cotbolt", "lohaya", "skadioo", "amkette", "redtech", "prushti",
    "lunagariya", "shopoflux", "10k", "king", "isoelite", "crossvolt", "dealfreez",
    "irusu", "goldmedal", "lava", "tuarso", "urbn", "opentech", "zodo", "envie",
    "supcares", "hb",     "csi",
    "activa",
    "rpm",
    "zinq",
    "akiara",     "morphy",
    "v-guard",
    "candes",
    "wecool",
    "astigo",
    "vu",    "airtel",
    "quantum",
    "karbonn",
    "tizum"
]

# Normalize: lowercase, remove duplicates, and sort
cleaned = sorted(set(item.lower() for item in BLOCKED_BRANDS))

# Print in the same format
result = ", ".join(f'"{item}"' for item in cleaned)
print(result)
# Out:
# "10k", "7seven", "activa", "agaro", "aircase", "airtel", "akiara", "ambrane", "amkette", "amozo", "astigo", "bajaj", "boat", "borosil", "boult", "bulfyss", "butterfly", "candes", "cello", "classmate", "cotbolt", "croma", "crompton", "crossvolt", "csi", "dealfreez", "digitek", "e cosmos", "e-cosmos", "ecosmos", "electvision", "elv", "envie", "eureka", "flix", "gizga", "goldmedal", "havells", "hb", "healthsense", "hul", "ibell", "inalsa", "instacuppa", "irusu", "isoelite", "karbonn", "kent", "king", "kitchen", "kuber", "lapster", "lava", "lifelong", "lint", "lohaya", "lunagariya", "maharaja", "morphy", "noise", "opentech", "orpat", "parker", "pigeon", "pinnaclz", "popio", "portronics", "prestige", "prettykrafts", "prushti", "ptron", "quantum", "redtech", "robustrion", "rpm", "shopoflux", "skadioo", "sounce", "storite", "striff", "sujata", "supcares", "swapkart", "synqe", "tata", "tizum", "tuarso", "tukzer", "tvara", "tygot", "urbn", "usha", "v-guard", "vu", "vw", "wayona", "wecool", "w
# ...
